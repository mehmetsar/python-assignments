# %%
name = input("Enter your name : ").title().strip()
my_name = "Mehmet"
if name==my_name:
  print("Hello, {}! The password is : abcd".format(my_name))
else :
  print("Hello, {}! See you later!".format(name))
# Out:
# Enter your name : mehmet
# Hello, Mehmet! The password is : abcd
